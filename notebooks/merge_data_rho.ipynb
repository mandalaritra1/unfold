# %%
import pickle as pkl
import hist
import numpy as np

# %%
outputs = [ pkl.load(open("./inputs/rho/rho_data_2016APV.pkl", "rb")),
            pkl.load(open("./inputs/rho/rho_data_2016.pkl", "rb")),
            pkl.load(open("./inputs/rho/rho_data_2017.pkl", "rb")),
            pkl.load(open("./inputs/rho/rho_data_2018.pkl", "rb"))
          ]


hist_keys = ['ptjet_rhojet_u_reco', 'ptjet_rhojet_g_reco']
out_dict = {}
for i, output in enumerate(outputs):
    for key in hist_keys:
        if i == 0:
            out_dict[key] = output[key].project('ptreco', 'mpt_reco', 'systematic')
        else:
            out_dict[key] += output[key].project('ptreco', 'mpt_reco', 'systematic')

pkl.dump(out_dict, open("./inputs/rho/rho_data_all.pkl", "wb"))

# %%
##V2

outputs = [ pkl.load(open("./inputs/rho/jms_dataV2_2016APV_syst.pkl", "rb")),
            pkl.load(open("./inputs/rho/jms_dataV2_2016_syst.pkl", "rb")),
            pkl.load(open("./inputs/rho/jms_dataV2_2017_syst.pkl", "rb")),
            pkl.load(open("./inputs/rho/jms_dataV2_2018_syst.pkl", "rb"))
          ]


hist_keys = ['ptjet_rhojet_u_reco', 'ptjet_rhojet_g_reco']
out_dict = {}
for i, output in enumerate(outputs):
    for key in hist_keys:
        if i == 0:
            out_dict[key] = output[key].project('ptreco', 'mpt_reco', 'systematic')
        else:
            out_dict[key] += output[key].project('ptreco', 'mpt_reco', 'systematic')

pkl.dump(out_dict, open("./inputs/rho/rho_dataV2_all.pkl", "wb"))

# %%
##V2 Data

outputs = [ pkl.load(open("./inputs/rho/jms_pythiaV2_2016APV_syst.pkl", "rb")),
            pkl.load(open("./inputs/rho/jms_pythiaV2_2016_syst.pkl", "rb")),
            pkl.load(open("./inputs/rho/jms_pythiaV2_2017_syst.pkl", "rb")),
            pkl.load(open("./inputs/rho/jms_pythiaV2_2018_syst.pkl", "rb"))
          ]


hist_keys = ['ptjet_rhojet_u_reco', 'ptjet_rhojet_g_reco', 'response_matrix_rho_u', 'response_matrix_rho_g', 'ptjet_rhojet_u_gen', 'ptjet_rhojet_g_gen',]
out_dict = {}
for i, output in enumerate(outputs):
    for key in hist_keys:
        if key in ['ptjet_rhojet_u_reco', 'ptjet_rhojet_g_reco']:
            if i == 0:
                out_dict[key] = output[key].project('ptreco', 'mpt_reco', 'systematic')
            else:
                out_dict[key] += output[key].project('ptreco', 'mpt_reco', 'systematic')
            print(f"Processed {key} for file {i}")
        elif key in ['response_matrix_rho_u', 'response_matrix_rho_g']:
            if i == 0:
                out_dict[key] = output[key].project('ptgen', 'mpt_gen', 'ptreco', 'mpt_reco', 'systematic')
            else:
                out_dict[key] += output[key].project('ptgen', 'mpt_gen', 'ptreco', 'mpt_reco', 'systematic')
            print(f"Processed {key} for file {i}")
        elif key in ['ptjet_rhojet_u_gen', 'ptjet_rhojet_g_gen']:
            if i == 0:
                out_dict[key] = output[key].project('ptgen', 'mpt_gen', 'systematic')
            else:
                out_dict[key] += output[key].project('ptgen', 'mpt_gen', 'systematic')
            print(f"Processed {key} for file {i}")

pkl.dump(out_dict, open("./inputs/rho/jms_pythiaV2_all_syst.pkl", "wb"))
# Out:
# Processed ptjet_rhojet_u_reco for file 0
# Processed ptjet_rhojet_g_reco for file 0
# Processed response_matrix_rho_u for file 0
# Processed response_matrix_rho_g for file 0
# Processed ptjet_rhojet_u_gen for file 0
# Processed ptjet_rhojet_g_gen for file 0
# Processed ptjet_rhojet_u_reco for file 1
# Processed ptjet_rhojet_g_reco for file 1
# Processed response_matrix_rho_u for file 1
# Processed response_matrix_rho_g for file 1
# Processed ptjet_rhojet_u_gen for file 1
# Processed ptjet_rhojet_g_gen for file 1
# Processed ptjet_rhojet_u_reco for file 2
# Processed ptjet_rhojet_g_reco for file 2
# Processed response_matrix_rho_u for file 2
# Processed response_matrix_rho_g for file 2
# Processed ptjet_rhojet_u_gen for file 2
# Processed ptjet_rhojet_g_gen for file 2
# Processed ptjet_rhojet_u_reco for file 3
# Processed ptjet_rhojet_g_reco for file 3
# Processed response_matrix_rho_u for file 3
# Processed response_matrix_rho_g for file 3
# Processed ptjet_rhojet_u_gen for file 3
# Processed ptjet_rhojet_g_gen for file 3
