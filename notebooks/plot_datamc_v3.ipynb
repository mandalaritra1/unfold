# %%
import sys, os
sys.path.insert(0, "./src")

# %%
import pickle
import mplhep as hep 
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('./inputs/all_backgrounds.pkl', 'rb') as f:
    all_bkgs = pickle.load(f)
with open('./inputs/pythia_2018_syst.pkl', 'rb') as f:
    pythia_syst = pickle.load(f)
with open('./inputs/data18_output_no_syst.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data['ptjet_mjet_u_reco'].project('ptreco', 'mreco')[1,:10].plot( color='black', label='Data')
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7d133b745d00>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
pythia_syst['ptjet_mjet_u_reco']
# Out:
# Hist(
#   StrCategory(['pythia_HT-100to200', 'pythia_HT-200to400', 'pythia_HT-800to1200', 'pythia_HT-1200to2500', 'pythia_HT-2500toInf', 'pythia_HT-400to600', 'pythia_HT-600to800'], name='dataset'),
#   StrCategory(['ee', 'mm'], growth=True, name='channel', label='Channel'),
#   Variable([0, 200, 290, 400, 13000], name='ptreco', label='$p_{T,RECO}$ (GeV)'),
#   Variable(array([   0.,    5.,   10.,   15.,   20.,   25.,   30.,   40.,   50.,
#          60.,   70.,   80.,   90.,  100.,  110.,  120.,  130.,  140.,
#         150.,  160.,  170.,  185.,  200.,  215., 1000.]), name='mreco', label='$m_{RECO}$ (GeV)'),
# ...

# %%
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7d136d195d00>, errorbar=None, legend_artist=None)]

# %%
pythia_syst['ptjet_mjet_u_reco'][{'systematic':'nominal'}].project('mreco').plot(histtype='fill', color='magenta', label='DYJetsToLL')
all_bkgs['ptjet_mjet_u_reco'].project('dataset', 'mreco')[{'dataset':['ww_UL18NanoAODv9', 'wz_UL18NanoAODv9', 'zz_UL18NanoAODv9', 'ttjets_UL18NanoAODv9']}].plot(stack = True, histtype='fill')
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7d13684ea870>, errorbar=None, legend_artist=None),
#  StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7d136dd743b0>, errorbar=None, legend_artist=None),
#  StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7d136833a8a0>, errorbar=None, legend_artist=None),
#  StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7d136833ab10>, errorbar=None, legend_artist=None)]

# %%
pythia_syst['ptjet_mjet_u_reco'][{'systematic':'nominal'}].project('ptreco','mreco')[1,:].plot(histtype='fill', color='magenta', label='DYJetsToLL')
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7d136837dd00>, errorbar=None, legend_artist=None)]
