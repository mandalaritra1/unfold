# %%
import ipywidgets as widgets

# %% [markdown]
# ## Response Matrices
# ### Groomed

# %% [markdown]
# <img src="plots/zjet/groomed_matrix.png" width="600">

# %% [markdown]
# ### Groomed Results

# %%
display(
Image(filename ="plots/zjet/results/groomed_unfolded_closure_1.png" ),
Image(filename ="plots/zjet/results/groomed_unfolded_closure_2.png" ),
Image(filename ="plots/zjet/results/groomed_unfolded_closure_3.png" ),
Image(filename ="plots/zjet/results/groomed_unfolded_closure_4.png" ))

# %% [markdown]
# # Unfolded Reuslts

# %% [markdown]
# <img src="plots/zjet/results/ungroomed_unfolded_closure_1.png" style="width: 100%; height: auto;">

# %%
from IPython.display import Image

# %%
Image(filename ="plots/zjet/results/groomed_unfolded_closure_1.png" )
